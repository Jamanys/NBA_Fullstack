# %%
import pandas as pd

# %%
sho = pd.read_csv('data/shootings.csv')
pla = pd.read_csv('data/players_stats.csv')
adj = pd.read_csv('data/adjusted_shooting.csv')
adv = pd.read_csv('data/advanced_stats.csv')

# %%
print('data/shootings.csv')
print(sho.columns)
print('data/players_stats.csv')
print(pla.columns)
print('data/adjusted_shooting.csv')
print(adj.columns)
print('data/advanced_stats.csv')
print(adv.columns)
# Out:
# data/shootings.csv
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        '% of FGA by Distance', '% of FGA by Distance.1',
#        '% of FGA by Distance.2', '% of FGA by Distance.3',
#        '% of FGA by Distance.4', '% of FGA by Distance.5', 'FG% by Distance',
#        'FG% by Distance.1', 'FG% by Distance.2', 'FG% by Distance.3',
#        'FG% by Distance.4', 'FG% by Distance.5', '% of FG Ast'd',
#        '% of FG Ast'd.1', 'Dunks', 'Dunks.1', 'Corner 3s', 'Corner 3s.1',
#        '1/2 Court', '1/2 Court.1', 'Unnamed: 30', '-additional'],
#       dtype='object')
# data/players_stats.csv
# Index(['Rk', 'Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP▼', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Trp-Dbl', 'Awards', 'Player-additional'],
# ...
